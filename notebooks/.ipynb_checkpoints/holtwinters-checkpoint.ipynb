# %%
using Flux
using Zygote: Buffer

using M4
# Out:
# ┌ Info: Precompiling M4 [2195a5f3-7642-4e25-ac27-a7b8005e7ce1]
# └ @ Base loading.jl:1273
# WARNING: using StatsBase.predict in module M4 conflicts with an existing identifier.
# ┌ Warning: /home/gleb/.julia/packages/Plots/12uaJ/src/Plots.jl/ is not an existing directory, Revise is not watching
# └ @ Revise /home/gleb/.julia/packages/Revise/SZ4ae/src/Revise.jl:489

# %%
train_dict = read_series("../data/M4/Train/Monthly-train.csv")
test_dict = read_series("../data/M4/Test/Monthly-test.csv")
info_dict = read_info("../data/M4/M4-info.csv")
# Out:
# Dict{String,SeriesInfo} with 100000 entries:
#   "M45761" => SeriesInfo("M45761", "Finance", 12, "Monthly", 18, 0010-09-30T12:…
#   "M26424" => SeriesInfo("M26424", "Demographic", 12, "Monthly", 18, 0092-04-30…
#   "Y8539"  => SeriesInfo("Y8539", "Micro", 1, "Yearly", 6, 0077-12-31T12:00:00)
#   "Y7057"  => SeriesInfo("Y7057", "Micro", 1, "Yearly", 6, 0069-01-01T12:00:00)
#   "D2238"  => SeriesInfo("D2238", "Finance", 1, "Daily", 14, 0001-03-30T12:00:0…
#   "Q7214"  => SeriesInfo("Q7214", "Micro", 4, "Quarterly", 8, 0091-01-31T12:00:…
#   "Y3211"  => SeriesInfo("Y3211", "Macro", 1, "Yearly", 6, 0085-12-31T12:00:00)
#   "Y5114"  => SeriesInfo("Y5114", "Micro", 1, "Yearly", 6, 0069-01-01T12:00:00)
#   "M16981" => SeriesInfo("M16981", "Micro", 12, "Monthly", 18, 0008-08-31T12:00…
#   "M44763" => SeriesInfo("M44763", "Finance", 12, "Monthly", 18, 0007-01-31T12:…
#   "M43839" => SeriesInfo("M43839", "Finance", 12, "Monthly", 18, 0087-12-31T12:…
# ...

# %%
series_id = "M3"
train_series = train_dict[series_id]
test_series = test_dict[series_id]
info = info_dict[series_id]

print(info)
plot_pieces(train_series, test_series)
# Out:
# SeriesInfo("M3", "Macro", 12, "Monthly", 18, 0076-06-01T12:00:00)

# %%
import M4: roll_window

input_size = info.freq * 5
output_size = info.horizon
windows = roll_window(train_series, input_size, output_size)
windows[1:3]
# Out:
# 3-element Array{Tuple{Array{Float64,1},Array{Float64,1}},1}:
#  ([2670.0, 2590.0, 2784.0, 2816.0, 2888.0, 2906.0, 2839.0, 2860.0, 2798.0, 2795.0  …  3380.0, 3573.0, 3516.0, 3527.0, 3613.0, 3589.0, 3525.0, 3662.0, 3605.0, 3563.0], [3527.0, 3502.0, 3594.0, 3767.0, 3705.0, 3676.0, 3819.0, 3845.0, 3773.0, 3770.0, 3791.0, 3740.0, 3802.0, 3779.0, 3806.0, 3958.0, 3920.0, 3948.0])
#  ([2590.0, 2784.0, 2816.0, 2888.0, 2906.0, 2839.0, 2860.0, 2798.0, 2795.0, 2796.0  …  3573.0, 3516.0, 3527.0, 3613.0, 3589.0, 3525.0, 3662.0, 3605.0, 3563.0, 3527.0], [3502.0, 3594.0, 3767.0, 3705.0, 3676.0, 3819.0, 3845.0, 3773.0, 3770.0, 3791.0, 3740.0, 3802.0, 3779.0, 3806.0, 3958.0, 3920.0, 3948.0, 4026.0])
# ...

# %%
struct HoltWintersParams
    input_size::Int64
    output_size::Int64
    freq::Int64
    
    level_smooth::Float64
    trend_smooth::Float64
    season_smooth::Float64
    
    level_start::Float64
    trend_start::Float64
    season_start::Float64
end

function seq_to_seq(params::HoltWintersParams)
    function (input::Vector{Float64})
        akp
        
        n = length(input) + 1
        
        level = Buffer([], Float64, n)
        level[1] = params.level_start[1]
        
        trend = Buffer([], Float64, n)
        trend[1] = params.trend_start[1]
        
        season = Bugger([], Float64, n)
        season[1]

        for t in 2:n
            level[t] = params.level_smooth * series[t - 1] + (1 - params.level_smooth) * (level[t - 1] + phi * trend[t - 1])
            trend[t] = beta * (level[t] - level[t - 1]) + (1 - beta) * phi * trend[t - 1]
            sea
        end
        
        copy(next)
    end
end

model = seq_to_seq(HoltWintersParams)
